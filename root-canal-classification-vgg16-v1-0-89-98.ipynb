# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array

from tensorflow.keras.applications.vgg16 import VGG16

# %% [markdown]
# ### IMPORTING / VIEWING / PREPROCESSING DATASET

# %% [markdown]
# > `DATA AUGMENTATION`

# %%
# Data Augmentation - Doing 80-20 split

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   zoom_range=0.2,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split=0.2)

# %%
train_dataset = train_datagen.flow_from_directory(directory = '../input/root-canal',
                                                  class_mode = 'categorical',
                                                  target_size = (224,224),
                                                  subset = 'training')
# Out:
# Found 92 images belonging to 2 classes.

# %%
valid_dataset  = valid_datagen.flow_from_directory(directory = '../input/root-canal',
                                                   class_mode = 'categorical',
                                                   target_size = (224,224),
                                                   subset = 'validation')
# Out:
# Found 23 images belonging to 2 classes.

# %%
# Checking the binary class labels.

train_dataset.class_indices
# Out:
# {'1_ROOT': 0, '2_MORE_ROOT': 1}

# %%
# Viewing Images 

fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(20,20))

for i in tqdm(range(0, 5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(len(train_dataset))
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title("1_ROOT")
    else:
        ax[i].set_title("2_MORE_ROOT")
# Out:
# 100%|██████████| 5/5 [00:04<00:00,  1.23it/s]

# %% [markdown]
# ### MODEL BUILDING

# %%
# Initializing VGG-16 model

base_model = VGG16(input_shape=(224,224,3), 
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 3s 0us/step

# %%
# Checking Summary 

base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))

# %%
# Checking Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25088)             100352
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 41,566,018
# Trainable params: 26,797,058
# Non-trainable params: 14,768,960
# _________________________________________________________________

# %%
# Checking imbalance in the data for setting metric.

root_1 = glob.glob('../input/root-canal/1_ROOT/1 root/*.jpg')
root_2 = glob.glob('../input/root-canal/2_MORE_ROOT/2 or more roots/*.jpg')

len(root_1), len(root_2)
# Out:
# (65, 50)

# %%
# Compiling Model

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 500,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/500
# 3/3 [==============================] - ETA: 0s - loss: 0.7642 - auc: 0.6793
# Epoch 00001: val_auc improved from -inf to 0.62004, saving model to ./best_weights.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.7642 - auc: 0.6793 - val_loss: 0.8983 - val_auc: 0.6200
# Epoch 2/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4145 - auc: 0.9047
# Epoch 00002: val_auc did not improve from 0.62004
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4145 - auc: 0.9047 - val_loss: 0.8606 - val_auc: 0.6040
# Epoch 3/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4912 - auc: 0.8898
# Epoch 00003: val_auc improved from 0.62004 to 0.82042, saving model to ./best_weights.hdf5
# 3/3 [==============================] - 2s 768ms/step - loss: 0.4912 - auc: 0.8898 - val_loss: 0.5104 - val_auc: 0.8204
# Epoch 4/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3686 - auc: 0.9395
# Epoch 00004: val_auc improved from 0.82042 to 0.89225, saving model to ./best_weights.hdf5
# 3/3 [==============================] - 2s 676ms/step - loss: 0.3686 - auc: 0.9395 - val_loss: 0.4125 - val_auc: 0.8922
# Epoch 5/500
# 3/3 [==============================] - ETA: 0s - loss: 0.5341 - auc: 0.8980
# Epoch 00005: val_auc improved from 0.89225 to 0.89414, saving model to ./best_weights.hdf5
# 3/3 [==============================] - 2s 637ms/step - loss: 0.5341 - auc: 0.8980 - val_loss: 0.3963 - val_auc: 0.8941
# Epoch 6/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2905 - auc: 0.9571
# Epoch 00006: val_auc did not improve from 0.89414
# 3/3 [==============================] - 1s 314ms/step - loss: 0.2905 - auc: 0.9571 - val_loss: 0.4258 - val_auc: 0.8941
# Epoch 7/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4471 - auc: 0.9257
# Epoch 00007: val_auc improved from 0.89414 to 0.89981, saving model to ./best_weights.hdf5
# 3/3 [==============================] - 4s 1s/step - loss: 0.4471 - auc: 0.9257 - val_loss: 0.4199 - val_auc: 0.8998
# Epoch 8/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3558 - auc: 0.9467
# Epoch 00008: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 326ms/step - loss: 0.3558 - auc: 0.9467 - val_loss: 0.8761 - val_auc: 0.7164
# Epoch 9/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2688 - auc: 0.9582
# Epoch 00009: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 322ms/step - loss: 0.2688 - auc: 0.9582 - val_loss: 1.5106 - val_auc: 0.6616
# Epoch 10/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3238 - auc: 0.9551
# Epoch 00010: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 319ms/step - loss: 0.3238 - auc: 0.9551 - val_loss: 1.4833 - val_auc: 0.6541
# Epoch 11/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1842 - auc: 0.9823
# Epoch 00011: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 290ms/step - loss: 0.1842 - auc: 0.9823 - val_loss: 0.9154 - val_auc: 0.6975
# Epoch 12/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2037 - auc: 0.9724
# Epoch 00012: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 322ms/step - loss: 0.2037 - auc: 0.9724 - val_loss: 0.5410 - val_auc: 0.8242
# Epoch 13/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2824 - auc: 0.9591
# Epoch 00013: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 319ms/step - loss: 0.2824 - auc: 0.9591 - val_loss: 0.4531 - val_auc: 0.8762
# Epoch 14/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1499 - auc: 0.9773
# Epoch 00014: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 407ms/step - loss: 0.1499 - auc: 0.9773 - val_loss: 0.5285 - val_auc: 0.8431
# Epoch 15/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1942 - auc: 0.9833
# Epoch 00015: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 303ms/step - loss: 0.1942 - auc: 0.9833 - val_loss: 0.6443 - val_auc: 0.7977
# Epoch 16/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3482 - auc: 0.9493
# Epoch 00016: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 373ms/step - loss: 0.3482 - auc: 0.9493 - val_loss: 0.7645 - val_auc: 0.7590
# Epoch 17/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2132 - auc: 0.9765
# Epoch 00017: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 303ms/step - loss: 0.2132 - auc: 0.9765 - val_loss: 0.7322 - val_auc: 0.7750
# Epoch 18/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1506 - auc: 0.9878
# Epoch 00018: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 385ms/step - loss: 0.1506 - auc: 0.9878 - val_loss: 0.6547 - val_auc: 0.8025
# Epoch 19/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1639 - auc: 0.9784
# Epoch 00019: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 320ms/step - loss: 0.1639 - auc: 0.9784 - val_loss: 0.6136 - val_auc: 0.8204
# Epoch 20/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1886 - auc: 0.9809
# Epoch 00020: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 307ms/step - loss: 0.1886 - auc: 0.9809 - val_loss: 0.6373 - val_auc: 0.8053
# Epoch 21/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1639 - auc: 0.9862
# Epoch 00021: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 329ms/step - loss: 0.1639 - auc: 0.9862 - val_loss: 0.6857 - val_auc: 0.7977
# Epoch 22/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2004 - auc: 0.9765
# Epoch 00022: val_auc did not improve from 0.89981
# 3/3 [==============================] - 1s 340ms/step - loss: 0.2004 - auc: 0.9765 - val_loss: 0.6979 - val_auc: 0.7958
# Epoch 00022: early stopping

# %% [markdown]
# ### MODEL EVALUATION

# %%
# LOSS 

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('LOSS')
plt.ylabel('Loss')
plt.xlabel('Nos. of epochs')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor = (1,1))
plt.show()

# %%
# AUC

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('AUC')
plt.ylabel('AUC')
plt.xlabel('Nos. of epochs')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor = (1,1))
plt.show()

# %%
# TESTING ON IMAGES

# %% [markdown]
# > `CASE 1: 1_ROOT IMAGE`

# %%
dict = train_dataset.class_indices
idc  = {k:v for v, k in dict.items()}

img = load_img('../input/root-canal/1_ROOT/1 root/tooth10.jpg', target_size=(224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
img = np.expand_dims(img, axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 96.42 % chances are there that the image is 1_ROOT

# %% [markdown]
# > `CASE 2: 2_MORE_ROOT`

# %%
dict = train_dataset.class_indices
idc  = {k:v for v, k in dict.items()}

img = load_img('../input/root-canal/2_MORE_ROOT/2 or more roots/tooth100.jpg', target_size=(224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
img = np.expand_dims(img, axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 83.85 % chances are there that the image is 2_MORE_ROOT
